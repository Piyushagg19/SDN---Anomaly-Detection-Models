# %% [markdown]
# <a href="https://colab.research.google.com/github/Piyushagg19/SDN---Anomaly-Detection-Models/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import DBSCAN
import sklearn.utils
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler
import pandas as pd

from google.colab import drive
drive.mount("/content/gdrive")

pd.options.mode.chained_assignment = None
# import pickle

# MODEL_FILE = 'models/trained_dbscan.pkl'
# SS_FILE = 'models/trained_ss.pkl'
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/training_data_pos.csv')

df.drop(columns=['time', 'eth_src', 'eth_dst', 'priority', 'class'], inplace=True)
df = df[1000:5000]

N = df.shape[0]

# %%
class Model:

    def __init__(self):
        # self.model = pickle.load(open(MODEL_FILE, 'rb'))
        # print("params : " + str(self.model.get_params()))
        self.model = DBSCAN(eps=2.5, min_samples=9, algorithm='ball_tree')

    def preprocess(self, df):
        # assigning weights based on out-port
        for indx, r in df.iterrows():
            weight_col = 'out-port-' + str(df.loc[indx, 'out-port'])
            weights = df.loc[indx, weight_col][1:-1]
            weights = weights.split(",")
            l = []
            for w in weights:
                if w != '':
                    l.append(int(w.strip()))

            df.loc[indx, 'weight'] = max(l, default=10)

        df.drop(columns=['out-port-1', 'out-port-2', 'out-port-3', 'out-port-4', 'out-port-5', 'out-port-6'],
                inplace=True)

        # normalizing data
        cols = ['total_packets', 'total_bytes', 'duration', 'weight']
        self.normalize(df, cols)
        return df

    def normalize(self, df, cols):
        df[cols] = df[cols].apply(pd.to_numeric)
        for col in cols:
            mean = df[col].mean()
            sd = df[col].std()
            if sd == 0:
                df[col] = 0
            else:
                df[col] = (df[col] - mean) / sd

    def fit(self, df):
        #print('inside fit')
        res = self.model.fit(df)
        self.res = res
        self.labels = res.labels_

    def predict(self, df):
        return self.model.fit_predict(df)

# %%
obj = Model()

i = 0
while i < N:
    temp_df = df[i: min(N, i + 100)]
    i += 100
    temp_df = obj.preprocess(temp_df)
    print(temp_df.shape)
    obj.fit(temp_df)
    n_clusters = len(set(obj.labels)) - (1 if -1 in obj.labels else 0)
    print('\nclusters : ' + str(n_clusters))
    n_outliers = list(obj.labels).count(-1)
    print('outliers : ' + str(n_outliers))
# Out:
# (100, 7)
#
# clusters : 1
# outliers : 50
# (100, 7)
#
# clusters : 1
# outliers : 37
# (100, 7)
#
# clusters : 1
# outliers : 38
# (100, 7)
#
# clusters : 4
# outliers : 48
# (100, 7)
#
# clusters : 1
# outliers : 42
# (100, 7)
#
# clusters : 2
# outliers : 54
# (100, 7)
#
# clusters : 1
# outliers : 34
# (100, 7)
#
# clusters : 3
# outliers : 36
# (100, 7)
#
# clusters : 1
# outliers : 36
# (100, 7)
#
# clusters : 1
# outliers : 53
# (100, 7)
#
# clusters : 1
# outliers : 58
# (100, 7)
#
# clusters : 3
# outliers : 61
# (100, 7)
#
# clusters : 2
# outliers : 46
# (100, 7)
#
# clusters : 3
# outliers : 61
# (100, 7)
#
# clusters : 1
# outliers : 60
# (100, 7)
#
# clusters : 1
# outliers : 34
# (100, 7)
#
# clusters : 3
# outliers : 50
# (100, 7)
#
# clusters : 1
# outliers : 45
# (100, 7)
#
# clusters : 1
# outliers : 56
# (100, 7)
#
# clusters : 3
# outliers : 53
# (100, 7)
#
# clusters : 2
# outliers : 74
# (100, 7)
#
# clusters : 3
# outliers : 48
# (100, 7)
#
# clusters : 3
# outliers : 45
# (100, 7)
#
# clusters : 1
# outliers : 40
# (100, 7)
#
# clusters : 1
# outliers : 66
# (100, 7)
#
# clusters : 3
# outliers : 40
# (100, 7)
#
# clusters : 1
# outliers : 50
# (100, 7)
#
# clusters : 2
# outliers : 38
# (100, 7)
#
# clusters : 2
# outliers : 57
# (100, 7)
#
# clusters : 1
# outliers : 59
# (100, 7)
#
# clusters : 1
# outliers : 38
# (100, 7)
#
# clusters : 1
# outliers : 45
# (100, 7)
#
# clusters : 1
# outliers : 44
# (100, 7)
#
# clusters : 1
# outliers : 34
# (100, 7)
#
# clusters : 1
# outliers : 54
# (100, 7)
#
# clusters : 3
# outliers : 45
# (100, 7)
#
# clusters : 1
# outliers : 57
# (100, 7)
#
# clusters : 1
# outliers : 30
# (100, 7)
#
# clusters : 2
# outliers : 31
# (100, 7)
#
# clusters : 2
# outliers : 32
